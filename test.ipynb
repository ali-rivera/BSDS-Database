# %% [markdown]
# Notebook for testing system manually. Currently just printing out all the datasets in the database.

# %%
from datasets.models import Dataset
from mongoengine import connect
import os
from dotenv import load_dotenv

load_dotenv()
#connect to MongoDB
connect(
    db="mongodb",                    # from MONGO_INIT_DB in your .env
    username="mongo",               # from MONGO_INITDB_ROOT_USERNAME
    password="BSDSDATABASE",        # from MONGO_INITDB_ROOT_PASSWORD
    host="localhost",
    port=27017,
    authentication_source="admin"
)
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, read_preference=Primary(), authsource='admin', uuidrepresentation=3, driver=DriverInfo(name='MongoEngine', version='0.29.1', platform=None))

# %%
#fetch all datasets
for d in Dataset.objects:
    print(f"{d.name} | {d.description} | {d.file_url}")

# %%
from mongoengine import disconnect
disconnect()
