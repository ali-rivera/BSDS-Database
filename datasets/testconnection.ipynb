# %%
import models
import pymongo
from models import Dataset
import datetime
import dotenv
import os
dotenv.load_dotenv()

MONGO_INITDB_ROOT_USERNAME = os.getenv('MONGO_INITDB_ROOT_USERNAME')
MONGO_INITDB_ROOT_PASSWORD = os.getenv('MONGO_INITDB_ROOT_PASSWORD')
myclient = pymongo.MongoClient(f"mongodb://{MONGO_INITDB_ROOT_USERNAME}:{MONGO_INITDB_ROOT_PASSWORD}@localhost:27017/")

#create an entry
dataset = Dataset(
    name="states_all_2_training.csv",
    description = "Inserting first test data set",
    file_url="https://github.com/UVADS/DS-3021/blob/main/Kaggle/states_all_2_training.csv",
    uploaded_at = datetime.datetime.utcnow()
    
)
dataset.save()

#fetch and print datasets
for d in Dataset.objects:
    print(d.name, d.file_url)
# Out:
# ---------------------------------------------------------------------------
# ConnectionFailure                         Traceback (most recent call last)
# Cell In[4], line 21
#      13 #create an entry
#      14 dataset = Dataset(
#      15     name="states_all_2_training.csv",
#      16     description = "Inserting first test data set",
#    (...)
#      19
#      20 )
# ---> 21 dataset.save()
#      23 #fetch and print datasets
#      24 for d in Dataset.objects:
#
# File /mnt/c/Users/krngz/OneDrive - University of Virginia/Active Learning Lab/BSDS_Database/BSDS-Database/.venv/lib/python3.10/site-packages/mongoengine/document.py:440, in Document.save(self, force_insert, validate, clean, write_concern, cascade, cascade_kwargs, _refs, save_condition, signal_kwargs, **kwargs)
#     436 # Initialize the Document's underlying pymongo.Collection (+create indexes) if not already initialized
# ...
